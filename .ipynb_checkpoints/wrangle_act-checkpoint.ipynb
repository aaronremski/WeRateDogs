# %% [markdown]
# # WeRateDogs - Udacity Data Wrangling Project 03
# ---
# ## 3 datasets
# 1. twitter-archive-enhanced.csv (local archive)
# 2. rt_tweets (obtained data via Twitter API, to get additional fields that coorespond to IDs in twitter_archive)
# 3. image_preds (local archive created from image recognition system
# ## 8 Quality Issues
# Also known as dirty data which includes mislabeled, corrupted, duplicated, inconsistent content issues
#
# ### twitter-archive-enhanced.csv quality issues:
#
# 1. columns 'timestamp' & 'retweeted_status_timestamp' are objects (strings) and not of 'timestamp' type
#
# 2. numerous dog names are "a"; Replace with np.NaN
#
# 3. doggo, floofer, pupper, & puppo use None; Replace with 0, and 1 where 'doggo, floofer, etc...'
#
# 4. remove URL from 'source' & replace with 4 categories: iphone, vine, twitter, tweetdeck
#
# 5. remove retweets
#
#
# ---
# ## 2 Tidiness Issues
# Messy data includes structural issues where variables don't form a column, observations form rows, & each observational unit forms a table.
#
#
# ### all 3 datasets tidiness issues:
#
# 1. merge all 3 datasets; remove unwanted columns
#
#
# ### image-predictions.tsv tidiness issues:
#
# 2. Messy data - variables form both rows and columns --> p1, p2, p3, p1_conf, p2_conf, p3_conf, etc. Pivot vars into 3 cols, prediction #, prediction name, prediction probability
#
# 3. Messy data - variables from both rows and columns --> doggo, floofer, pupper, puppo. Presumably the dog should only have 1 name? If so, this issue can been resolved with imperfection (which name to select when 2 or more given). If not, and multiple 'doggo' names are allowed, then this issue becomes moot.

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import numpy as np
import os
import requests

import tweepy
from tweepy import OAuthHandler
import json
from timeit import default_timer as timer

# %% [markdown]
# ## Gather Data #1 - Twitter archive

# %%
twitterDF = pd.read_csv("data/twitter-archive-enhanced.csv")
twitterDF.head(5)
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
# 2  891815181378084864                    NaN                  NaN
# 3  891689557279858688                    NaN                  NaN
# 4  891327558926688256                    NaN                  NaN
#
#                    timestamp  \
# 0  2017-08-01 16:23:56 +0000
# 1  2017-08-01 00:17:27 +0000
# 2  2017-07-31 00:18:03 +0000
# 3  2017-07-30 15:58:51 +0000
# 4  2017-07-29 16:00:24 +0000
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
#                                                 text  retweeted_status_id  \
# 0  This is Phineas. He's a mystical boy. Only eve...                  NaN
# 1  This is Tilly. She's just checking pup on you....                  NaN
# 2  This is Archie. He is a rare Norwegian Pouncin...                  NaN
# 3  This is Darla. She commenced a snooze mid meal...                  NaN
# 4  This is Franklin. He would like you to stop ca...                  NaN
#
#    retweeted_status_user_id retweeted_status_timestamp  \
# 0                       NaN                        NaN
# 1                       NaN                        NaN
# 2                       NaN                        NaN
# 3                       NaN                        NaN
# 4                       NaN                        NaN
#
#                                        expanded_urls  rating_numerator  \
# 0  https://twitter.com/dog_rates/status/892420643...                13
# 1  https://twitter.com/dog_rates/status/892177421...                13
# 2  https://twitter.com/dog_rates/status/891815181...                12
# 3  https://twitter.com/dog_rates/status/891689557...                13
# 4  https://twitter.com/dog_rates/status/891327558...                12
#
#    rating_denominator      name doggo floofer pupper puppo
# 0                  10   Phineas  None    None   None  None
# 1                  10     Tilly  None    None   None  None
# 2                  10    Archie  None    None   None  None
# 3                  10     Darla  None    None   None  None
# 4                  10  Franklin  None    None   None  None

# %%
# review data columns in DF, are Dtypes appropriate, etc.
twitterDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   tweet_id                    2356 non-null   int64
#  1   in_reply_to_status_id       78 non-null     float64
#  2   in_reply_to_user_id         78 non-null     float64
#  3   timestamp                   2356 non-null   object
#  4   source                      2356 non-null   object
#  5   text                        2356 non-null   object
#  6   retweeted_status_id         181 non-null    float64
#  7   retweeted_status_user_id    181 non-null    float64
#  8   retweeted_status_timestamp  181 non-null    object
#  9   expanded_urls               2297 non-null   object
#  10  rating_numerator            2356 non-null   int64
#  11  rating_denominator          2356 non-null   int64
#  12  name                        2356 non-null   object
#  13  doggo                       2356 non-null   object
#  14  floofer                     2356 non-null   object
#  15  pupper                      2356 non-null   object
#  16  puppo                       2356 non-null   object
# dtypes: float64(4), int64(3), object(10)
# memory usage: 313.0+ KB

# %%
# review names of pups
twitterDF.name.value_counts()
# Out:
# None        745
# a            55
# Charlie      12
# Oliver       11
# Lucy         11
#            ...
# Baron         1
# Jennifur      1
# Jonah         1
# Cedrick       1
# Zooey         1
# Name: name, Length: 957, dtype: int64

# %%
# review dogtionary names; interesting to see id# 200 has 2 values, doggo & floofer
twitterDF[twitterDF['floofer'] != 'None'].head(3)
# Out:
#                tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 46   883360690899218434                    NaN                  NaN
# 200  854010172552949760                    NaN                  NaN
# 582  800388270626521089                    NaN                  NaN
#
#                      timestamp  \
# 46   2017-07-07 16:22:55 +0000
# 200  2017-04-17 16:34:26 +0000
# 582  2016-11-20 17:20:08 +0000
#
#                                                 source  \
# 46   <a href="http://twitter.com/download/iphone" r...
# 200  <a href="http://twitter.com/download/iphone" r...
# 582  <a href="http://twitter.com/download/iphone" r...
#
#                                                   text  retweeted_status_id  \
# 46   Meet Grizzwald. He may be the floofiest floofe...                  NaN
# 200  At first I thought this was a shy doggo, but i...                  NaN
# 582  This is Doc. He takes time out of every day to...                  NaN
#
#      retweeted_status_user_id retweeted_status_timestamp  \
# 46                        NaN                        NaN
# 200                       NaN                        NaN
# 582                       NaN                        NaN
#
#                                          expanded_urls  rating_numerator  \
# 46   https://twitter.com/dog_rates/status/883360690...                13
# 200  https://twitter.com/dog_rates/status/854010172...                11
# 582  https://twitter.com/dog_rates/status/800388270...                12
#
#      rating_denominator       name  doggo  floofer pupper puppo
# 46                   10  Grizzwald   None  floofer   None  None
# 200                  10       None  doggo  floofer   None  None
# 582                  10        Doc   None  floofer   None  None

# %%
# it appears the designations were pulled from the tweeted text, 'doggo' & 'floofer' in text below
twitterDF.loc[200,'text']
# Out:
# "At first I thought this was a shy doggo, but it's actually a Rare Canadian Floofer Owl. Amateurs would confuse the two. 11/10 only send dogs https://t.co/TXdT3tmuYk"

# %%
# Illustrating that pup designations are NOT singular. Multiple 
twitterDF[twitterDF['doggo'] != 'None'].sample(5)
# Out:
#                tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 575  801115127852503040                    NaN                  NaN
# 835  768193404517830656                    NaN                  NaN
# 985  749075273010798592                    NaN                  NaN
# 318  834574053763584002                    NaN                  NaN
# 108  871515927908634625                    NaN                  NaN
#
#                      timestamp  \
# 575  2016-11-22 17:28:25 +0000
# 835  2016-08-23 21:09:14 +0000
# 985  2016-07-02 03:00:36 +0000
# 318  2017-02-23 01:22:14 +0000
# 108  2017-06-04 23:56:03 +0000
#
#                                                 source  \
# 575  <a href="http://twitter.com/download/iphone" r...
# 835  <a href="http://twitter.com/download/iphone" r...
# 985  <a href="http://vine.co" rel="nofollow">Vine -...
# 318  <a href="http://twitter.com/download/iphone" r...
# 108  <a href="http://twitter.com/download/iphone" r...
#
#                                                   text  retweeted_status_id  \
# 575  This is Bones. He's being haunted by another d...                  NaN
# 835  Meet Gerald. He's a fairly exotic doggo. Floof...                  NaN
# 985  This is Boomer. He's self-baptizing. Other dog...                  NaN
# 318  Here's a doggo fully pupared for a shower. H*c...                  NaN
# 108  This is Napolean. He's a Raggedy East Nicaragu...                  NaN
#
#      retweeted_status_user_id retweeted_status_timestamp  \
# 575                       NaN                        NaN
# 835                       NaN                        NaN
# 985                       NaN                        NaN
# 318                       NaN                        NaN
# 108                       NaN                        NaN
#
#                                          expanded_urls  rating_numerator  \
# 575  https://twitter.com/dog_rates/status/801115127...                12
# 835  https://twitter.com/dog_rates/status/768193404...                 8
# 985                      https://vine.co/v/5ztZvHgI17r                11
# 318  https://twitter.com/dog_rates/status/834574053...                13
# 108  https://twitter.com/dog_rates/status/871515927...                12
#
#      rating_denominator      name  doggo floofer  pupper puppo
# 575                  10     Bones  doggo    None  pupper  None
# 835                  10    Gerald  doggo    None    None  None
# 985                  10    Boomer  doggo    None    None  None
# 318                  10      None  doggo    None    None  None
# 108                  10  Napolean  doggo    None    None  None

# %% [markdown]
# ## Q1 - Convert dtype of timestamp columns
# Q1 = Quality Item #1

# %%
# Fixed 2 columns with incorrect datatypes, changed to datetime64
twitterDF.timestamp = pd.to_datetime(twitterDF.timestamp)
twitterDF.retweeted_status_timestamp = pd.to_datetime(twitterDF.retweeted_status_timestamp)
twitterDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   tweet_id                    2356 non-null   int64
#  1   in_reply_to_status_id       78 non-null     float64
#  2   in_reply_to_user_id         78 non-null     float64
#  3   timestamp                   2356 non-null   datetime64[ns, UTC]
#  4   source                      2356 non-null   object
#  5   text                        2356 non-null   object
#  6   retweeted_status_id         181 non-null    float64
#  7   retweeted_status_user_id    181 non-null    float64
#  8   retweeted_status_timestamp  181 non-null    datetime64[ns, UTC]
#  9   expanded_urls               2297 non-null   object
#  10  rating_numerator            2356 non-null   int64
#  11  rating_denominator          2356 non-null   int64
#  12  name                        2356 non-null   object
#  13  doggo                       2356 non-null   object
#  14  floofer                     2356 non-null   object
#  15  pupper                      2356 non-null   object
#  16  puppo                       2356 non-null   object
# dtypes: datetime64[ns, UTC](2), float64(4), int64(3), object(8)
# memory usage: 313.0+ KB

# %% [markdown]
# ## Q2 - dog names = 'a', replace with NaN

# %%
# replace puppo's names that match 'a' with NaN
twitterDF.name = np.where(twitterDF.name == 'a', np.NaN, twitterDF.name)

# %%
# check to ensure all 'a' names were removed 
twitterDF[twitterDF.name == 'a']
# Out:
# Empty DataFrame
# Columns: [tweet_id, in_reply_to_status_id, in_reply_to_user_id, timestamp, source, text, retweeted_status_id, retweeted_status_user_id, retweeted_status_timestamp, expanded_urls, rating_numerator, rating_denominator, name, doggo, floofer, pupper, puppo]
# Index: []

# %% [markdown]
# ## Q3 - doggo, floofer, pupper, & puppo use None; Replace with NaN, or 0, & 1 for present

# %%
# replace 'None' with 0
# replace 'doggo' with 1
twitterDF.doggo = np.where(twitterDF.doggo == 'None', 0, twitterDF.doggo)
twitterDF.doggo = np.where(twitterDF.doggo == 'doggo', 1, twitterDF.doggo)

# %%
# replace 'None' with 0
# replace 'floofer' with 1
twitterDF.floofer = np.where(twitterDF.floofer == 'None', 0, twitterDF.floofer)
twitterDF.floofer = np.where(twitterDF.floofer == 'floofer', 1, twitterDF.floofer)

# %%
# replace 'None' with 0
# replace 'pupper' with 1
twitterDF.pupper = np.where(twitterDF.pupper == 'None', 0, twitterDF.pupper)
twitterDF.pupper = np.where(twitterDF.pupper == 'pupper', 1, twitterDF.pupper)

# %%
# replace 'None' with 0
# replace 'puppo' with 1
twitterDF.puppo = np.where(twitterDF.puppo == 'None', 0, twitterDF.puppo)
twitterDF.puppo = np.where(twitterDF.puppo == 'puppo', 1, twitterDF.puppo)

# %%
# check to ensure cleaning successful
twitterDF[twitterDF.puppo == 'None'].count()
# Out:
# tweet_id                      0
# in_reply_to_status_id         0
# in_reply_to_user_id           0
# timestamp                     0
# source                        0
# text                          0
# retweeted_status_id           0
# retweeted_status_user_id      0
# retweeted_status_timestamp    0
# expanded_urls                 0
# rating_numerator              0
# rating_denominator            0
# name                          0
# doggo                         0
# floofer                       0
# pupper                        0
# puppo                         0
# dtype: int64

# %%
# check to ensure cleaning successful
twitterDF.query("floofer == 1")
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 46    883360690899218434                    NaN                  NaN
# 200   854010172552949760                    NaN                  NaN
# 582   800388270626521089                    NaN                  NaN
# 774   776218204058357768                    NaN                  NaN
# 984   749317047558017024                    NaN                  NaN
# 1022  746542875601690625                    NaN                  NaN
# 1091  737445876994609152                    NaN                  NaN
# 1110  733822306246479872                    NaN                  NaN
# 1534  689993469801164801                    NaN                  NaN
# 1614  685307451701334016                    NaN                  NaN
#
#                      timestamp  \
# 46   2017-07-07 16:22:55+00:00
# 200  2017-04-17 16:34:26+00:00
# 582  2016-11-20 17:20:08+00:00
# 774  2016-09-15 00:36:55+00:00
# 984  2016-07-02 19:01:20+00:00
# 1022 2016-06-25 03:17:46+00:00
# 1091 2016-05-31 00:49:32+00:00
# 1110 2016-05-21 00:50:46+00:00
# 1534 2016-01-21 02:10:37+00:00
# 1614 2016-01-08 03:50:03+00:00
#
#                                                  source  \
# 46    <a href="http://twitter.com/download/iphone" r...
# 200   <a href="http://twitter.com/download/iphone" r...
# 582   <a href="http://twitter.com/download/iphone" r...
# 774   <a href="http://twitter.com/download/iphone" r...
# 984   <a href="http://twitter.com/download/iphone" r...
# 1022  <a href="http://vine.co" rel="nofollow">Vine -...
# 1091  <a href="http://twitter.com/download/iphone" r...
# 1110  <a href="http://twitter.com/download/iphone" r...
# 1534  <a href="http://vine.co" rel="nofollow">Vine -...
# 1614  <a href="http://twitter.com/download/iphone" r...
#
#                                                    text  retweeted_status_id  \
# 46    Meet Grizzwald. He may be the floofiest floofe...                  NaN
# 200   At first I thought this was a shy doggo, but i...                  NaN
# 582   This is Doc. He takes time out of every day to...                  NaN
# 774   Atlas rolled around in some chalk and now he's...                  NaN
# 984   This is Blu. He's a wild bush Floofer. I wish ...                  NaN
# 1022  Here's a golden floofer helping with the groce...                  NaN
# 1091  Just wanted to share this super rare Rainbow F...                  NaN
# 1110  This is Moose. He's a Polynesian Floofer. Dapp...                  NaN
# 1534  Here we are witnessing a rare High Stepping Al...                  NaN
# 1614  Say hello to Petrick. He's an Altostratus Floo...                  NaN
#
#       retweeted_status_user_id retweeted_status_timestamp  \
# 46                         NaN                        NaT
# 200                        NaN                        NaT
# 582                        NaN                        NaT
# 774                        NaN                        NaT
# 984                        NaN                        NaT
# 1022                       NaN                        NaT
# 1091                       NaN                        NaT
# 1110                       NaN                        NaT
# 1534                       NaN                        NaT
# 1614                       NaN                        NaT
#
#                                           expanded_urls  rating_numerator  \
# 46    https://twitter.com/dog_rates/status/883360690...                13
# 200   https://twitter.com/dog_rates/status/854010172...                11
# 582   https://twitter.com/dog_rates/status/800388270...                12
# 774   https://twitter.com/dog_rates/status/776218204...                13
# 984   https://twitter.com/dog_rates/status/749317047...                12
# 1022                      https://vine.co/v/5uZYwqmuDeT                11
# 1091  https://twitter.com/dog_rates/status/737445876...                13
# 1110  https://twitter.com/dog_rates/status/733822306...                10
# 1534                      https://vine.co/v/ienexVMZgi5                12
# 1614  https://twitter.com/dog_rates/status/685307451...                11
#
#       rating_denominator       name doggo floofer pupper puppo
# 46                    10  Grizzwald     0       1      0     0
# 200                   10       None     1       1      0     0
# 582                   10        Doc     0       1      0     0
# 774                   10       None     0       1      0     0
# 984                   10        Blu     0       1      0     0
# 1022                  10       None     0       1      0     0
# 1091                  10       None     0       1      0     0
# 1110                  10      Moose     0       1      0     0
# 1534                  10       None     0       1      0     0
# 1614                  10    Petrick     0       1      0     0

# %% [markdown]
# ## Q4 - remove URL from 'source' & replace with 4 categories: iphone, vine, twitter, tweetdeck

# %%
# review names of sources
twitterDF.source.value_counts()
# Out:
# <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>     2221
# <a href="http://vine.co" rel="nofollow">Vine - Make a Scene</a>                          91
# <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>                       33
# <a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>      11
# Name: source, dtype: int64

# %%
twitterDF.head(2)
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
#
#                   timestamp  \
# 0 2017-08-01 16:23:56+00:00
# 1 2017-08-01 00:17:27+00:00
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
#
#                                                 text  retweeted_status_id  \
# 0  This is Phineas. He's a mystical boy. Only eve...                  NaN
# 1  This is Tilly. She's just checking pup on you....                  NaN
#
#    retweeted_status_user_id retweeted_status_timestamp  \
# 0                       NaN                        NaT
# 1                       NaN                        NaT
#
#                                        expanded_urls  rating_numerator  \
# 0  https://twitter.com/dog_rates/status/892420643...                13
# 1  https://twitter.com/dog_rates/status/892177421...                13
#
#    rating_denominator     name doggo floofer pupper puppo
# 0                  10  Phineas     0       0      0     0
# 1                  10    Tilly     0       0      0     0

# %%
# function to categorize source column

def update_source(row):
    if 'iphone' in row:
        return 'iphone'
    elif 'vine' in row:
        return 'vine'
    elif 'Twitter' in row:
        return 'twitter web client'
    elif 'TweetDeck' in row:
        return 'TweetDeck'

# %%
# run update_source function on every row to replace source text with shorter description of source
twitterDF.source = twitterDF.apply(lambda row: update_source(row['source']),axis=1)

# %%
# check to ensure function replaced items as intended
twitterDF.sample(5)
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 191   855851453814013952                    NaN                  NaN
# 285   838916489579200512                    NaN                  NaN
# 2034  671743150407421952                    NaN                  NaN
# 948   752334515931054080                    NaN                  NaN
# 749   779124354206535695                    NaN                  NaN
#
#                      timestamp  source  \
# 191  2017-04-22 18:31:02+00:00  iphone
# 285  2017-03-07 00:57:32+00:00  iphone
# 2034 2015-12-01 17:30:22+00:00  iphone
# 948  2016-07-11 02:51:40+00:00  iphone
# 749  2016-09-23 01:04:56+00:00  iphone
#
#                                                    text  retweeted_status_id  \
# 191   Here's a puppo participating in the #ScienceMa...                  NaN
# 285   RT @KibaDva: I collected all the good dogs!! 1...         8.389060e+17
# 2034  This is a Tuscaloosa Alcatraz named Jacob (Yac...                  NaN
# 948   Here's a doggo trying to catch some fish. 8/10...                  NaN
# 749   RT @dog_rates: Meet Hurley. He's the curly one...         6.794628e+17
#
#       retweeted_status_user_id retweeted_status_timestamp  \
# 191                        NaN                        NaT
# 285               8.117408e+08  2017-03-07 00:15:46+00:00
# 2034                       NaN                        NaT
# 948                        NaN                        NaT
# 749               4.196984e+09  2015-12-23 00:45:35+00:00
#
#                                           expanded_urls  rating_numerator  \
# 191   https://twitter.com/dog_rates/status/855851453...                13
# 285   https://twitter.com/KibaDva/status/83890598062...                15
# 2034  https://twitter.com/dog_rates/status/671743150...                11
# 948   https://twitter.com/dog_rates/status/752334515...                 8
# 749   https://twitter.com/dog_rates/status/679462823...                11
#
#       rating_denominator    name doggo floofer pupper puppo
# 191                   10    None     1       0      0     1
# 285                   10    None     0       0      0     0
# 2034                  10     NaN     0       0      0     0
# 948                   10    None     1       0      0     0
# 749                   10  Hurley     0       0      0     0

# %% [markdown]
# ## Q5 - remove retweets & delete columns

# %%
twitterDF.sample(2)
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 1244  711743778164514816                    NaN                  NaN
# 1800  676975532580409345                    NaN                  NaN
#
#                      timestamp  source  \
# 1244 2016-03-21 02:38:34+00:00  iphone
# 1800 2015-12-16 04:01:59+00:00  iphone
#
#                                                    text  retweeted_status_id  \
# 1244  Meet Roosevelt. He's calculating the best case...                  NaN
# 1800  This is Cooper. He doesn't know how cheese wor...                  NaN
#
#       retweeted_status_user_id retweeted_status_timestamp  \
# 1244                       NaN                        NaT
# 1800                       NaN                        NaT
#
#                                           expanded_urls  rating_numerator  \
# 1244  https://twitter.com/dog_rates/status/711743778...                11
# 1800  https://twitter.com/dog_rates/status/676975532...                11
#
#       rating_denominator       name doggo floofer pupper puppo
# 1244                  10  Roosevelt     0       0      0     0
# 1800                  10     Cooper     0       0      0     0

# %%
twitterDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   tweet_id                    2356 non-null   int64
#  1   in_reply_to_status_id       78 non-null     float64
#  2   in_reply_to_user_id         78 non-null     float64
#  3   timestamp                   2356 non-null   datetime64[ns, UTC]
#  4   source                      2356 non-null   object
#  5   text                        2356 non-null   object
#  6   retweeted_status_id         181 non-null    float64
#  7   retweeted_status_user_id    181 non-null    float64
#  8   retweeted_status_timestamp  181 non-null    datetime64[ns, UTC]
#  9   expanded_urls               2297 non-null   object
#  10  rating_numerator            2356 non-null   int64
#  11  rating_denominator          2356 non-null   int64
#  12  name                        2301 non-null   object
#  13  doggo                       2356 non-null   object
#  14  floofer                     2356 non-null   object
#  15  pupper                      2356 non-null   object
#  16  puppo                       2356 non-null   object
# dtypes: datetime64[ns, UTC](2), float64(4), int64(3), object(8)
# memory usage: 313.0+ KB

# %%
# Get indices of rows to drop, in this case, any row with a value in retweeted_status_id different that NaN.  
drop_these = twitterDF[twitterDF['retweeted_status_id'].notnull()].index
twitterDF.drop(drop_these,inplace=True)
twitterDF.sample(3)
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 1461  694925794720792577                    NaN                  NaN
# 1223  714251586676113411                    NaN                  NaN
# 591   799063482566066176                    NaN                  NaN
#
#                      timestamp  source  \
# 1461 2016-02-03 16:49:55+00:00    vine
# 1223 2016-03-28 00:43:43+00:00  iphone
# 591  2016-11-17 01:35:54+00:00  iphone
#
#                                                    text  retweeted_status_id  \
# 1461  Please only send in dogs. This t-rex is very s...                  NaN
# 1223  This is Thumas. He hates potted plants. 8/10 w...                  NaN
# 591   This is Mister. He only wears the most fashion...                  NaN
#
#       retweeted_status_user_id retweeted_status_timestamp  \
# 1461                       NaN                        NaT
# 1223                       NaN                        NaT
# 591                        NaN                        NaT
#
#                                           expanded_urls  rating_numerator  \
# 1461                      https://vine.co/v/iJvUqWQ166L                 5
# 1223  https://twitter.com/dog_rates/status/714251586...                 8
# 591   https://twitter.com/dog_rates/status/799063482...                11
#
#       rating_denominator    name doggo floofer pupper puppo
# 1461                  10    None     0       0      0     0
# 1223                  10  Thumas     0       0      0     0
# 591                   10  Mister     0       0      0     0

# %%
# check if any 'notnull' entries exist in retweeted_status_id
twitterDF[twitterDF['retweeted_status_id'].notnull()]
# Out:
# Empty DataFrame
# Columns: [tweet_id, in_reply_to_status_id, in_reply_to_user_id, timestamp, source, text, retweeted_status_id, retweeted_status_user_id, retweeted_status_timestamp, expanded_urls, rating_numerator, rating_denominator, name, doggo, floofer, pupper, puppo]
# Index: []

# %%
twitterDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2175 entries, 0 to 2355
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   tweet_id                    2175 non-null   int64
#  1   in_reply_to_status_id       78 non-null     float64
#  2   in_reply_to_user_id         78 non-null     float64
#  3   timestamp                   2175 non-null   datetime64[ns, UTC]
#  4   source                      2175 non-null   object
#  5   text                        2175 non-null   object
#  6   retweeted_status_id         0 non-null      float64
#  7   retweeted_status_user_id    0 non-null      float64
#  8   retweeted_status_timestamp  0 non-null      datetime64[ns, UTC]
#  9   expanded_urls               2117 non-null   object
#  10  rating_numerator            2175 non-null   int64
#  11  rating_denominator          2175 non-null   int64
#  12  name                        2120 non-null   object
#  13  doggo                       2175 non-null   object
#  14  floofer                     2175 non-null   object
#  15  pupper                      2175 non-null   object
#  16  puppo                       2175 non-null   object
# dtypes: datetime64[ns, UTC](2), float64(4), int64(3), object(8)
# memory usage: 305.9+ KB

# %%
# get rid of 3 empty columns representing the retweeted tweets
drop_cols = ['retweeted_status_id','retweeted_status_user_id','retweeted_status_timestamp']
twitterDF.drop(drop_cols,axis=1,inplace=True)
twitterDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2175 entries, 0 to 2355
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   tweet_id               2175 non-null   int64
#  1   in_reply_to_status_id  78 non-null     float64
#  2   in_reply_to_user_id    78 non-null     float64
#  3   timestamp              2175 non-null   datetime64[ns, UTC]
#  4   source                 2175 non-null   object
#  5   text                   2175 non-null   object
#  6   expanded_urls          2117 non-null   object
#  7   rating_numerator       2175 non-null   int64
#  8   rating_denominator     2175 non-null   int64
#  9   name                   2120 non-null   object
#  10  doggo                  2175 non-null   object
#  11  floofer                2175 non-null   object
#  12  pupper                 2175 non-null   object
#  13  puppo                  2175 non-null   object
# dtypes: datetime64[ns, UTC](1), float64(2), int64(3), object(8)
# memory usage: 254.9+ KB

# %%
# data exploration
# see sample of is_reply_to_status_id...
twitterDF[twitterDF.in_reply_to_status_id.notnull()]
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 30    886267009285017600           8.862664e+17         2.281182e+09
# 55    881633300179243008           8.816070e+17         4.738443e+07
# 64    879674319642796034           8.795538e+17         3.105441e+09
# 113   870726314365509632           8.707262e+17         1.648776e+07
# 148   863427515083354112           8.634256e+17         7.759620e+07
# ...                  ...                    ...                  ...
# 2038  671550332464455680           6.715449e+17         4.196984e+09
# 2149  669684865554620416           6.693544e+17         4.196984e+09
# 2169  669353438988365824           6.678065e+17         4.196984e+09
# 2189  668967877119254528           6.689207e+17         2.143566e+07
# 2298  667070482143944705           6.670655e+17         4.196984e+09
#
#                      timestamp  source  \
# 30   2017-07-15 16:51:35+00:00  iphone
# 55   2017-07-02 21:58:53+00:00  iphone
# 64   2017-06-27 12:14:36+00:00  iphone
# 113  2017-06-02 19:38:25+00:00  iphone
# 148  2017-05-13 16:15:35+00:00  iphone
# ...                        ...     ...
# 2038 2015-12-01 04:44:10+00:00  iphone
# 2149 2015-11-26 01:11:28+00:00  iphone
# 2169 2015-11-25 03:14:30+00:00  iphone
# 2189 2015-11-24 01:42:25+00:00  iphone
# 2298 2015-11-18 20:02:51+00:00  iphone
#
#                                                    text  \
# 30    @NonWhiteHat @MayhewMayhem omg hello tanner yo...
# 55    @roushfenway These are good dogs but 17/10 is ...
# 64                      @RealKentMurphy 14/10 confirmed
# 113   @ComplicitOwl @ShopWeRateDogs &gt;10/10 is res...
# 148   @Jack_Septic_Eye I'd need a few more pics to p...
# ...                                                 ...
# 2038  After 22 minutes of careful deliberation this ...
# 2149  After countless hours of research and hundreds...
# 2169  This is Tessa. She is also very pleased after ...
# 2189                     12/10 good shit Bubka\n@wane15
# 2298  After much debate this dog is being upgraded t...
#
#                                           expanded_urls  rating_numerator  \
# 30                                                  NaN                12
# 55                                                  NaN                17
# 64                                                  NaN                14
# 113                                                 NaN                10
# 148                                                 NaN                12
# ...                                                 ...               ...
# 2038                                                NaN                 1
# 2149                                                NaN                11
# 2169  https://twitter.com/dog_rates/status/669353438...                10
# 2189                                                NaN                12
# 2298                                                NaN                10
#
#       rating_denominator   name doggo floofer pupper puppo
# 30                    10   None     0       0      0     0
# 55                    10   None     0       0      0     0
# 64                    10   None     0       0      0     0
# 113                   10   None     0       0      0     0
# 148                   10   None     0       0      0     0
# ...                  ...    ...   ...     ...    ...   ...
# 2038                  10   None     0       0      0     0
# 2149                  10   None     0       0      0     0
# 2169                  10  Tessa     0       0      0     0
# 2189                  10   None     0       0      0     0
# 2298                  10   None     0       0      0     0
#
# [78 rows x 14 columns]

# %% [markdown]
# ## Gather Data #2 - Tweet image predictions

# %%
# Download data from file_url utilizing requests library & save to line#5
file_url = "https://d17h27t6h515a5.cloudfront.net/topher/2017/August/599fd2ad_image-predictions/image-predictions.tsv"
req = requests.get(file_url)
fname = os.path.basename(file_url)
open("data/" + fname, 'wb').write(req.content)

# %%
# data exploration
# Nows read file downloaded & view sample
image_preds = pd.read_csv("data/image-predictions.tsv", sep="\t")
image_preds.sample(5)
# Out:
#                 tweet_id                                          jpg_url  \
# 1661  811744202451197953  https://pbs.twimg.com/media/C0PlCQjXAAA9TIh.jpg
# 395   673636718965334016  https://pbs.twimg.com/media/CVk9ApFWUAA-S1s.jpg
# 438   674422304705744896  https://pbs.twimg.com/media/CVwHgblWcAACWOD.jpg
# 38    666644823164719104  https://pbs.twimg.com/media/CUBl6IwVAAA9_zT.jpg
# 1958  865359393868664832  https://pbs.twimg.com/media/DAJfxqGVoAAnvQt.jpg
#
#       img_num                        p1   p1_conf  p1_dog                  p2  \
# 1661        1                  Pekinese  0.386082    True  Labrador_retriever
# 395         1                    wombat  0.880257   False                corn
# 438         1          golden_retriever  0.964497    True  Labrador_retriever
# 38          1              Ibizan_hound  0.044333    True            Pembroke
# 1958        2  Chesapeake_Bay_retriever  0.832435    True  Labrador_retriever
#
#        p2_conf  p2_dog                           p3   p3_conf  p3_dog
# 1661  0.202862    True             golden_retriever  0.170487    True
# 395   0.019421   False                          pug  0.019044    True
# 438   0.009006    True                  tennis_ball  0.007139   False
# 38    0.043209    True  West_Highland_white_terrier  0.038906    True
# 1958  0.163551    True                   Weimaraner  0.002770    True

# %%
# data exploration
image_preds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075 entries, 0 to 2074
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   tweet_id  2075 non-null   int64
#  1   jpg_url   2075 non-null   object
#  2   img_num   2075 non-null   int64
#  3   p1        2075 non-null   object
#  4   p1_conf   2075 non-null   float64
#  5   p1_dog    2075 non-null   bool
#  6   p2        2075 non-null   object
#  7   p2_conf   2075 non-null   float64
#  8   p2_dog    2075 non-null   bool
#  9   p3        2075 non-null   object
#  10  p3_conf   2075 non-null   float64
#  11  p3_dog    2075 non-null   bool
# dtypes: bool(3), float64(3), int64(2), object(4)
# memory usage: 152.1+ KB

# %% [markdown]
# ## Gather Data #3 - Query Twitter API for additional data
# Query Twitter's API for JSON data for each tweet ID in the Twitter archive
#
#  * retweet count
#  * favorite count
#  * any additional data found that's interesting
#  * only tweets on Aug 1st, 2017 (image predictions present)

# %%
# define keys & API info 
# authenticate API using regenerated keys/tokens

consumer_key = 'HIDDEN'
consumer_secret = 'HIDDEN'
access_token = 'HIDDEN'
access_secret = 'HIDDEN'

auth = OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)

api = tweepy.API(auth, wait_on_rate_limit=True)

# %%
tweet_ids = twitterDF.tweet_id.values
len(tweet_ids)

# %%
# Query Twitter's API for JSON data for each tweet ID in the Twitter archive
count = 0
fails_dict = {}
start = timer()
# Save each tweet's returned JSON as a new line in a .txt file
with open('tweet_json.txt', 'w') as outfile:
    # This loop will likely take 20-30 minutes to run because of Twitter's rate limit
    for tweet_id in tweet_ids:
        count += 1
        print(str(count) + ": " + str(tweet_id))
        try:
            tweet = api.get_status(tweet_id, tweet_mode='extended')
            print("Success")
            json.dump(tweet._json, outfile)
            outfile.write('\n')
        except tweepy.TweepError as e:
            print("Fail")
            fails_dict[tweet_id] = e
            pass
end = timer()
print(end - start)
print(fails_dict)

# %% [markdown]
# ### Start from here if data already obtained from Twitter

# %%
# Read tweet JSON into dataframe using pandas
# recived ValueError: Trailing data without 'lines=True'

rt_tweets = pd.read_json("tweet.json", lines=True)
rt_tweets.head(5)
# Out:
#                  created_at                  id              id_str  \
# 0 2017-08-01 16:23:56+00:00  892420643555336193  892420643555336192
# 1 2017-08-01 00:17:27+00:00  892177421306343426  892177421306343424
# 2 2017-07-31 00:18:03+00:00  891815181378084864  891815181378084864
# 3 2017-07-30 15:58:51+00:00  891689557279858688  891689557279858688
# 4 2017-07-29 16:00:24+00:00  891327558926688256  891327558926688256
#
#                                            full_text  truncated  \
# 0  This is Phineas. He's a mystical boy. Only eve...      False
# 1  This is Tilly. She's just checking pup on you....      False
# 2  This is Archie. He is a rare Norwegian Pouncin...      False
# 3  This is Darla. She commenced a snooze mid meal...      False
# 4  This is Franklin. He would like you to stop ca...      False
#
#   display_text_range                                           entities  \
# 0            [0, 85]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 1           [0, 138]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 2           [0, 121]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 3            [0, 79]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 4           [0, 138]  {'hashtags': [{'text': 'BarkWeek', 'indices': ...
#
#                                    extended_entities  \
# 0  {'media': [{'id': 892420639486877696, 'id_str'...
# 1  {'media': [{'id': 892177413194625024, 'id_str'...
# 2  {'media': [{'id': 891815175371796480, 'id_str'...
# 3  {'media': [{'id': 891689552724799489, 'id_str'...
# 4  {'media': [{'id': 891327551943041024, 'id_str'...
#
#                                               source  in_reply_to_status_id  \
# 0  <a href="http://twitter.com/download/iphone" r...                    NaN
# 1  <a href="http://twitter.com/download/iphone" r...                    NaN
# 2  <a href="http://twitter.com/download/iphone" r...                    NaN
# 3  <a href="http://twitter.com/download/iphone" r...                    NaN
# 4  <a href="http://twitter.com/download/iphone" r...                    NaN
#
#    ...  favorited  retweeted  possibly_sensitive  \
# 0  ...      False      False                 0.0
# 1  ...      False      False                 0.0
# 2  ...      False      False                 0.0
# 3  ...      False      False                 0.0
# 4  ...      False      False                 0.0
#
#   possibly_sensitive_appealable lang  retweeted_status  quoted_status_id  \
# 0                           0.0   en               NaN               NaN
# 1                           0.0   en               NaN               NaN
# 2                           0.0   en               NaN               NaN
# 3                           0.0   en               NaN               NaN
# 4                           0.0   en               NaN               NaN
#
#   quoted_status_id_str  quoted_status_permalink  quoted_status
# 0                  NaN                      NaN            NaN
# 1                  NaN                      NaN            NaN
# 2                  NaN                      NaN            NaN
# 3                  NaN                      NaN            NaN
# 4                  NaN                      NaN            NaN
#
# [5 rows x 32 columns]

# %%
# data exploration
rt_tweets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2330 entries, 0 to 2329
# Data columns (total 32 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   created_at                     2330 non-null   datetime64[ns, UTC]
#  1   id                             2330 non-null   int64
#  2   id_str                         2330 non-null   int64
#  3   full_text                      2330 non-null   object
#  4   truncated                      2330 non-null   bool
#  5   display_text_range             2330 non-null   object
#  6   entities                       2330 non-null   object
#  7   extended_entities              2058 non-null   object
#  8   source                         2330 non-null   object
#  9   in_reply_to_status_id          77 non-null     float64
#  10  in_reply_to_status_id_str      77 non-null     float64
#  11  in_reply_to_user_id            77 non-null     float64
#  12  in_reply_to_user_id_str        77 non-null     float64
#  13  in_reply_to_screen_name        77 non-null     object
#  14  user                           2330 non-null   object
#  15  geo                            0 non-null      float64
#  16  coordinates                    0 non-null      float64
#  17  place                          1 non-null      object
#  18  contributors                   0 non-null      float64
#  19  is_quote_status                2330 non-null   bool
#  20  retweet_count                  2330 non-null   int64
#  21  favorite_count                 2330 non-null   int64
#  22  favorited                      2330 non-null   bool
#  23  retweeted                      2330 non-null   bool
#  24  possibly_sensitive             2196 non-null   float64
#  25  possibly_sensitive_appealable  2196 non-null   float64
#  26  lang                           2330 non-null   object
#  27  retweeted_status               163 non-null    object
#  28  quoted_status_id               26 non-null     float64
#  29  quoted_status_id_str           26 non-null     float64
#  30  quoted_status_permalink        26 non-null     object
#  31  quoted_status                  24 non-null     object
# dtypes: bool(4), datetime64[ns, UTC](1), float64(11), int64(4), object(12)
# memory usage: 518.9+ KB

# %%
# data exploration
rt_tweets[rt_tweets.retweeted_status.notnull()].head(5)
# Out:
#                   created_at                  id              id_str  \
# 31 2017-07-15 02:45:48+00:00  886054160059072513  886054160059072512
# 35 2017-07-13 01:35:06+00:00  885311592912609280  885311592912609280
# 67 2017-06-26 00:13:58+00:00  879130579576475649  879130579576475648
# 72 2017-06-24 00:09:53+00:00  878404777348136964  878404777348136960
# 73 2017-06-23 18:17:33+00:00  878316110768087041  878316110768087040
#
#                                             full_text  truncated  \
# 31  RT @Athletics: 12/10 #BATP https://t.co/WxwJmv...      False
# 35  RT @dog_rates: This is Lilly. She just paralle...      False
# 67  RT @dog_rates: This is Emmy. She was adopted t...      False
# 72  RT @dog_rates: Meet Shadow. In an attempt to r...      False
# 73  RT @dog_rates: Meet Terrance. He's being yelle...      False
#
#    display_text_range                                           entities  \
# 31            [0, 50]  {'hashtags': [{'text': 'BATP', 'indices': [21,...
# 35           [0, 133]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 67           [0, 140]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 72           [0, 140]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 73           [0, 140]  {'hashtags': [], 'symbols': [], 'user_mentions...
#
#                                     extended_entities  \
# 31                                                NaN
# 35  {'media': [{'id': 830583314243268608, 'id_str'...
# 67                                                NaN
# 72                                                NaN
# 73                                                NaN
#
#                                                source  in_reply_to_status_id  \
# 31  <a href="http://twitter.com/download/iphone" r...                    NaN
# 35  <a href="http://twitter.com/download/iphone" r...                    NaN
# 67  <a href="http://twitter.com/download/iphone" r...                    NaN
# 72  <a href="http://twitter.com/download/iphone" r...                    NaN
# 73  <a href="http://twitter.com/download/iphone" r...                    NaN
#
#     ...  favorited  retweeted  possibly_sensitive  \
# 31  ...      False      False                 0.0
# 35  ...      False      False                 0.0
# 67  ...      False      False                 NaN
# 72  ...      False      False                 NaN
# 73  ...      False      False                 NaN
#
#    possibly_sensitive_appealable lang  \
# 31                           0.0  und
# 35                           0.0   en
# 67                           NaN   en
# 72                           NaN   en
# 73                           NaN   en
#
#                                      retweeted_status  quoted_status_id  \
# 31  {'created_at': 'Sat Jul 15 02:44:07 +0000 2017...      8.860534e+17
# 35  {'created_at': 'Sun Feb 12 01:04:29 +0000 2017...               NaN
# 67  {'created_at': 'Fri Jun 23 01:10:23 +0000 2017...               NaN
# 72  {'created_at': 'Fri Jun 23 16:00:04 +0000 2017...               NaN
# 73  {'created_at': 'Tue Nov 24 03:51:38 +0000 2015...               NaN
#
#    quoted_status_id_str                            quoted_status_permalink  \
# 31         8.860534e+17  {'url': 'https://t.co/WxwJmvjfxo', 'expanded':...
# 35                  NaN                                                NaN
# 67                  NaN                                                NaN
# 72                  NaN                                                NaN
# 73                  NaN                                                NaN
#
#     quoted_status
# 31            NaN
# 35            NaN
# 67            NaN
# 72            NaN
# 73            NaN
#
# [5 rows x 32 columns]

# %%
# data exploration
rt_tweets.user
# Out:
# 0       {'id': 4196983835, 'id_str': '4196983835', 'na...
# 1       {'id': 4196983835, 'id_str': '4196983835', 'na...
# 2       {'id': 4196983835, 'id_str': '4196983835', 'na...
# 3       {'id': 4196983835, 'id_str': '4196983835', 'na...
# 4       {'id': 4196983835, 'id_str': '4196983835', 'na...
#                               ...
# 2325    {'id': 4196983835, 'id_str': '4196983835', 'na...
# 2326    {'id': 4196983835, 'id_str': '4196983835', 'na...
# 2327    {'id': 4196983835, 'id_str': '4196983835', 'na...
# 2328    {'id': 4196983835, 'id_str': '4196983835', 'na...
# 2329    {'id': 4196983835, 'id_str': '4196983835', 'na...
# Name: user, Length: 2330, dtype: object

# %%
# data exploration
rt_tweets.columns
# Out:
# Index(['created_at', 'id', 'id_str', 'full_text', 'truncated',
#        'display_text_range', 'entities', 'extended_entities', 'source',
#        'in_reply_to_status_id', 'in_reply_to_status_id_str',
#        'in_reply_to_user_id', 'in_reply_to_user_id_str',
#        'in_reply_to_screen_name', 'user', 'geo', 'coordinates', 'place',
#        'contributors', 'is_quote_status', 'retweet_count', 'favorite_count',
#        'favorited', 'retweeted', 'possibly_sensitive',
#        'possibly_sensitive_appealable', 'lang', 'retweeted_status',
#        'quoted_status_id', 'quoted_status_id_str', 'quoted_status_permalink',
#        'quoted_status'],
#       dtype='object')

# %%
# data exploration
# inspect the extended entities data
rt_tweets.loc[0,'extended_entities']
# Out:
# {'media': [{'id': 892420639486877696,
#    'id_str': '892420639486877696',
#    'indices': [86, 109],
#    'media_url': 'http://pbs.twimg.com/media/DGKD1-bXoAAIAUK.jpg',
#    'media_url_https': 'https://pbs.twimg.com/media/DGKD1-bXoAAIAUK.jpg',
#    'url': 'https://t.co/MgUWQ76dJU',
#    'display_url': 'pic.twitter.com/MgUWQ76dJU',
#    'expanded_url': 'https://twitter.com/dog_rates/status/892420643555336193/photo/1',
#    'type': 'photo',
#    'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#     'medium': {'w': 540, 'h': 528, 'resize': 'fit'},
#     'small': {'w': 540, 'h': 528, 'resize': 'fit'},
#     'large': {'w': 540, 'h': 528, 'resize': 'fit'}}}]}

# %%
# data exploration
# inspect the entities data
rt_tweets.loc[115,'entities']
# Out:
# {'hashtags': [],
#  'symbols': [],
#  'user_mentions': [],
#  'urls': [],
#  'media': [{'id': 869702951354474496,
#    'id_str': '869702951354474496',
#    'indices': [140, 163],
#    'media_url': 'http://pbs.twimg.com/media/DBHOOfOXoAABKlU.jpg',
#    'media_url_https': 'https://pbs.twimg.com/media/DBHOOfOXoAABKlU.jpg',
#    'url': 'https://t.co/vmCu3PFCQq',
#    'display_url': 'pic.twitter.com/vmCu3PFCQq',
#    'expanded_url': 'https://twitter.com/dog_rates/status/869702957897576449/photo/1',
#    'type': 'photo',
#    'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#     'large': {'w': 901, 'h': 1600, 'resize': 'fit'},
#     'small': {'w': 383, 'h': 680, 'resize': 'fit'},
#     'medium': {'w': 676, 'h': 1200, 'resize': 'fit'}}}]}

# %%
# data exploration
rt_tweets.loc[130,'user']
# Out:
# {'id': 4196983835,
#  'id_str': '4196983835',
#  'name': 'WeRateDogs®',
#  'screen_name': 'dog_rates',
#  'location': 'merch ➜',
#  'description': 'Your Only Source For Professional Dog Ratings Instagram and Facebook ➜ WeRateDogs partnerships@weratedogs.com ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀',
#  'url': 'https://t.co/N7sNNHSfPq',
#  'entities': {'url': {'urls': [{'url': 'https://t.co/N7sNNHSfPq',
#      'expanded_url': 'http://weratedogs.com',
#      'display_url': 'weratedogs.com',
#      'indices': [0, 23]}]},
#   'description': {'urls': []}},
#  'protected': False,
#  'followers_count': 8894598,
#  'friends_count': 18,
#  'listed_count': 6035,
#  'created_at': 'Sun Nov 15 21:41:29 +0000 2015',
#  'favourites_count': 145946,
#  'utc_offset': None,
#  'time_zone': None,
#  'geo_enabled': True,
#  'verified': True,
#  'statuses_count': 13082,
#  'lang': None,
#  'contributors_enabled': False,
#  'is_translator': False,
#  'is_translation_enabled': False,
#  'profile_background_color': '000000',
#  'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#  'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#  'profile_background_tile': False,
#  'profile_image_url': 'http://pbs.twimg.com/profile_images/1322993722691211264/vyjR1ftm_normal.jpg',
#  'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1322993722691211264/vyjR1ftm_normal.jpg',
#  'profile_banner_url': 'https://pbs.twimg.com/profile_banners/4196983835/1591077312',
#  'profile_link_color': 'F5ABB5',
#  'profile_sidebar_border_color': '000000',
#  'profile_sidebar_fill_color': '000000',
#  'profile_text_color': '000000',
#  'profile_use_background_image': False,
#  'has_extended_profile': False,
#  'default_profile': False,
#  'default_profile_image': False,
#  'following': False,
#  'follow_request_sent': False,
#  'notifications': False,
#  'translator_type': 'none'}

# %%
# data exploration
rt_tweets.iloc[1:8,11:]
# Out:
#    in_reply_to_user_id  in_reply_to_user_id_str in_reply_to_screen_name  \
# 1                  NaN                      NaN                    None
# 2                  NaN                      NaN                    None
# 3                  NaN                      NaN                    None
# 4                  NaN                      NaN                    None
# 5                  NaN                      NaN                    None
# 6                  NaN                      NaN                    None
# 7                  NaN                      NaN                    None
#
#                                                 user  geo  coordinates place  \
# 1  {'id': 4196983835, 'id_str': '4196983835', 'na...  NaN          NaN  None
# 2  {'id': 4196983835, 'id_str': '4196983835', 'na...  NaN          NaN  None
# 3  {'id': 4196983835, 'id_str': '4196983835', 'na...  NaN          NaN  None
# 4  {'id': 4196983835, 'id_str': '4196983835', 'na...  NaN          NaN  None
# 5  {'id': 4196983835, 'id_str': '4196983835', 'na...  NaN          NaN  None
# 6  {'id': 4196983835, 'id_str': '4196983835', 'na...  NaN          NaN  None
# 7  {'id': 4196983835, 'id_str': '4196983835', 'na...  NaN          NaN  None
#
#    contributors  is_quote_status  retweet_count  ...  favorited  retweeted  \
# 1           NaN            False           5549  ...      False      False
# 2           NaN            False           3671  ...      False      False
# 3           NaN            False           7649  ...      False      False
# 4           NaN            False           8249  ...      False      False
# 5           NaN            False           2759  ...      False      False
# 6           NaN            False           1791  ...      False      False
# 7           NaN            False          16725  ...      False      False
#
#    possibly_sensitive  possibly_sensitive_appealable  lang retweeted_status  \
# 1                 0.0                            0.0    en              NaN
# 2                 0.0                            0.0    en              NaN
# 3                 0.0                            0.0    en              NaN
# 4                 0.0                            0.0    en              NaN
# 5                 0.0                            0.0    en              NaN
# 6                 0.0                            0.0    en              NaN
# 7                 0.0                            0.0    en              NaN
#
#   quoted_status_id  quoted_status_id_str  quoted_status_permalink  \
# 1              NaN                   NaN                      NaN
# 2              NaN                   NaN                      NaN
# 3              NaN                   NaN                      NaN
# 4              NaN                   NaN                      NaN
# 5              NaN                   NaN                      NaN
# 6              NaN                   NaN                      NaN
# 7              NaN                   NaN                      NaN
#
#   quoted_status
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# 5           NaN
# 6           NaN
# 7           NaN
#
# [7 rows x 21 columns]

# %%
# keeping only records of tweets that are NOT retweeted. Should have 2167 after filtering out non-null values of retweeted_status
rt_tweets = rt_tweets[rt_tweets.retweeted_status.isnull()]
rt_tweets.sample(2)
# Out:
#                     created_at                  id              id_str  \
# 1487 2016-01-24 18:09:23+00:00  691321916024623104  691321916024623104
# 1586 2016-01-08 05:00:14+00:00  685325112850124800  685325112850124800
#
#                                               full_text  truncated  \
# 1487  This is Molly. She's a Peruvian Niddlewog. Lov...      False
# 1586  "Tristan do not speak to me with that kind of ...      False
#
#      display_text_range                                           entities  \
# 1487           [0, 109]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 1586           [0, 111]  {'hashtags': [], 'symbols': [], 'user_mentions...
#
#                                       extended_entities  \
# 1487  {'media': [{'id': 691321897217191936, 'id_str'...
# 1586  {'media': [{'id': 685325091882799104, 'id_str'...
#
#                                                  source  \
# 1487  <a href="http://twitter.com/download/iphone" r...
# 1586  <a href="http://twitter.com/download/iphone" r...
#
#       in_reply_to_status_id  ...  favorited  retweeted  possibly_sensitive  \
# 1487                    NaN  ...      False      False                 0.0
# 1586                    NaN  ...      False      False                 0.0
#
#      possibly_sensitive_appealable lang  retweeted_status  quoted_status_id  \
# 1487                           0.0   en               NaN               NaN
# 1586                           0.0   en               NaN               NaN
#
#      quoted_status_id_str  quoted_status_permalink  quoted_status
# 1487                  NaN                      NaN            NaN
# 1586                  NaN                      NaN            NaN
#
# [2 rows x 32 columns]

# %%
# add columns to this list for creating a new DF with only columns we want only
tweet_cols = ['created_at','id','full_text','display_text_range','retweet_count','favorite_count','user']

# %%
# create new DF with column defined above
rt_tweets_sub = rt_tweets.loc[:,tweet_cols]
rt_tweets_sub.head(10)
# Out:
#                  created_at                  id  \
# 0 2017-08-01 16:23:56+00:00  892420643555336193
# 1 2017-08-01 00:17:27+00:00  892177421306343426
# 2 2017-07-31 00:18:03+00:00  891815181378084864
# 3 2017-07-30 15:58:51+00:00  891689557279858688
# 4 2017-07-29 16:00:24+00:00  891327558926688256
# 5 2017-07-29 00:08:17+00:00  891087950875897856
# 6 2017-07-28 16:27:12+00:00  890971913173991426
# 7 2017-07-28 00:22:40+00:00  890729181411237888
# 8 2017-07-27 16:25:51+00:00  890609185150312448
# 9 2017-07-26 15:59:51+00:00  890240255349198849
#
#                                            full_text display_text_range  \
# 0  This is Phineas. He's a mystical boy. Only eve...            [0, 85]
# 1  This is Tilly. She's just checking pup on you....           [0, 138]
# 2  This is Archie. He is a rare Norwegian Pouncin...           [0, 121]
# 3  This is Darla. She commenced a snooze mid meal...            [0, 79]
# 4  This is Franklin. He would like you to stop ca...           [0, 138]
# 5  Here we have a majestic great white breaching ...           [0, 138]
# 6  Meet Jax. He enjoys ice cream so much he gets ...           [0, 140]
# 7  When you watch your owner call another dog a g...           [0, 118]
# 8  This is Zoey. She doesn't want to be one of th...           [0, 122]
# 9  This is Cassie. She is a college pup. Studying...           [0, 133]
#
#    retweet_count  favorite_count  \
# 0           7477           35388
# 1           5549           30638
# 2           3671           23034
# 3           7649           38689
# 4           8249           36965
# 5           2759           18630
# 6           1791           10828
# 7          16725           59634
# 8           3815           25645
# 9           6490           29261
#
#                                                 user
# 0  {'id': 4196983835, 'id_str': '4196983835', 'na...
# 1  {'id': 4196983835, 'id_str': '4196983835', 'na...
# 2  {'id': 4196983835, 'id_str': '4196983835', 'na...
# 3  {'id': 4196983835, 'id_str': '4196983835', 'na...
# 4  {'id': 4196983835, 'id_str': '4196983835', 'na...
# 5  {'id': 4196983835, 'id_str': '4196983835', 'na...
# 6  {'id': 4196983835, 'id_str': '4196983835', 'na...
# 7  {'id': 4196983835, 'id_str': '4196983835', 'na...
# 8  {'id': 4196983835, 'id_str': '4196983835', 'na...
# 9  {'id': 4196983835, 'id_str': '4196983835', 'na...

# %%
rt_tweets.drop('retweeted_status',axis=1,inplace=True)
rt_tweets.columns
# Out:
# Index(['created_at', 'id', 'id_str', 'full_text', 'truncated',
#        'display_text_range', 'entities', 'extended_entities', 'source',
#        'in_reply_to_status_id', 'in_reply_to_status_id_str',
#        'in_reply_to_user_id', 'in_reply_to_user_id_str',
#        'in_reply_to_screen_name', 'user', 'geo', 'coordinates', 'place',
#        'contributors', 'is_quote_status', 'retweet_count', 'favorite_count',
#        'favorited', 'retweeted', 'possibly_sensitive',
#        'possibly_sensitive_appealable', 'lang', 'quoted_status_id',
#        'quoted_status_id_str', 'quoted_status_permalink', 'quoted_status'],
#       dtype='object')

# %% [markdown]
# ## Merge 3 datasets
#
# 1. twitterDF
# 2. rt_tweets_sub
# 3. image_preds

# %%
# data exploration
twitterDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2175 entries, 0 to 2355
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   tweet_id               2175 non-null   int64
#  1   in_reply_to_status_id  78 non-null     float64
#  2   in_reply_to_user_id    78 non-null     float64
#  3   timestamp              2175 non-null   datetime64[ns, UTC]
#  4   source                 2175 non-null   object
#  5   text                   2175 non-null   object
#  6   expanded_urls          2117 non-null   object
#  7   rating_numerator       2175 non-null   int64
#  8   rating_denominator     2175 non-null   int64
#  9   name                   2120 non-null   object
#  10  doggo                  2175 non-null   object
#  11  floofer                2175 non-null   object
#  12  pupper                 2175 non-null   object
#  13  puppo                  2175 non-null   object
# dtypes: datetime64[ns, UTC](1), float64(2), int64(3), object(8)
# memory usage: 254.9+ KB

# %%
# data exploration
rt_tweets_sub.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2167 entries, 0 to 2329
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   created_at          2167 non-null   datetime64[ns, UTC]
#  1   id                  2167 non-null   int64
#  2   full_text           2167 non-null   object
#  3   display_text_range  2167 non-null   object
#  4   retweet_count       2167 non-null   int64
#  5   favorite_count      2167 non-null   int64
#  6   user                2167 non-null   object
# dtypes: datetime64[ns, UTC](1), int64(3), object(3)
# memory usage: 135.4+ KB

# %%
image_preds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075 entries, 0 to 2074
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   tweet_id  2075 non-null   int64
#  1   jpg_url   2075 non-null   object
#  2   img_num   2075 non-null   int64
#  3   p1        2075 non-null   object
#  4   p1_conf   2075 non-null   float64
#  5   p1_dog    2075 non-null   bool
#  6   p2        2075 non-null   object
#  7   p2_conf   2075 non-null   float64
#  8   p2_dog    2075 non-null   bool
#  9   p3        2075 non-null   object
#  10  p3_conf   2075 non-null   float64
#  11  p3_dog    2075 non-null   bool
# dtypes: bool(3), float64(3), int64(2), object(4)
# memory usage: 152.1+ KB

# %%
# dataframe has a different name for its shared column, id --> tweet_id
rt_tweets_sub = rt_tweets_sub.rename(columns={"id":"tweet_id"})
rt_tweets_sub.head(5)
# Out:
#                  created_at            tweet_id  \
# 0 2017-08-01 16:23:56+00:00  892420643555336193
# 1 2017-08-01 00:17:27+00:00  892177421306343426
# 2 2017-07-31 00:18:03+00:00  891815181378084864
# 3 2017-07-30 15:58:51+00:00  891689557279858688
# 4 2017-07-29 16:00:24+00:00  891327558926688256
#
#                                            full_text display_text_range  \
# 0  This is Phineas. He's a mystical boy. Only eve...            [0, 85]
# 1  This is Tilly. She's just checking pup on you....           [0, 138]
# 2  This is Archie. He is a rare Norwegian Pouncin...           [0, 121]
# 3  This is Darla. She commenced a snooze mid meal...            [0, 79]
# 4  This is Franklin. He would like you to stop ca...           [0, 138]
#
#    retweet_count  favorite_count  \
# 0           7477           35388
# 1           5549           30638
# 2           3671           23034
# 3           7649           38689
# 4           8249           36965
#
#                                                 user
# 0  {'id': 4196983835, 'id_str': '4196983835', 'na...
# 1  {'id': 4196983835, 'id_str': '4196983835', 'na...
# 2  {'id': 4196983835, 'id_str': '4196983835', 'na...
# 3  {'id': 4196983835, 'id_str': '4196983835', 'na...
# 4  {'id': 4196983835, 'id_str': '4196983835', 'na...

# %%
# MERGE 2 dataframes!
new_tweets_df = pd.merge(rt_tweets_sub, twitterDF, on='tweet_id')
new_tweets_df.head(3)
# Out:
#                  created_at            tweet_id  \
# 0 2017-08-01 16:23:56+00:00  892420643555336193
# 1 2017-08-01 00:17:27+00:00  892177421306343426
# 2 2017-07-31 00:18:03+00:00  891815181378084864
#
#                                            full_text display_text_range  \
# 0  This is Phineas. He's a mystical boy. Only eve...            [0, 85]
# 1  This is Tilly. She's just checking pup on you....           [0, 138]
# 2  This is Archie. He is a rare Norwegian Pouncin...           [0, 121]
#
#    retweet_count  favorite_count  \
# 0           7477           35388
# 1           5549           30638
# 2           3671           23034
#
#                                                 user  in_reply_to_status_id  \
# 0  {'id': 4196983835, 'id_str': '4196983835', 'na...                    NaN
# 1  {'id': 4196983835, 'id_str': '4196983835', 'na...                    NaN
# 2  {'id': 4196983835, 'id_str': '4196983835', 'na...                    NaN
#
#    in_reply_to_user_id                 timestamp  source  \
# 0                  NaN 2017-08-01 16:23:56+00:00  iphone
# 1                  NaN 2017-08-01 00:17:27+00:00  iphone
# 2                  NaN 2017-07-31 00:18:03+00:00  iphone
#
#                                                 text  \
# 0  This is Phineas. He's a mystical boy. Only eve...
# 1  This is Tilly. She's just checking pup on you....
# 2  This is Archie. He is a rare Norwegian Pouncin...
#
#                                        expanded_urls  rating_numerator  \
# 0  https://twitter.com/dog_rates/status/892420643...                13
# 1  https://twitter.com/dog_rates/status/892177421...                13
# 2  https://twitter.com/dog_rates/status/891815181...                12
#
#    rating_denominator     name doggo floofer pupper puppo
# 0                  10  Phineas     0       0      0     0
# 1                  10    Tilly     0       0      0     0
# 2                  10   Archie     0       0      0     0

# %%
# data exploration
new_tweets_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2167 entries, 0 to 2166
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   created_at             2167 non-null   datetime64[ns, UTC]
#  1   tweet_id               2167 non-null   int64
#  2   full_text              2167 non-null   object
#  3   display_text_range     2167 non-null   object
#  4   retweet_count          2167 non-null   int64
#  5   favorite_count         2167 non-null   int64
#  6   user                   2167 non-null   object
#  7   in_reply_to_status_id  78 non-null     float64
#  8   in_reply_to_user_id    78 non-null     float64
#  9   timestamp              2167 non-null   datetime64[ns, UTC]
#  10  source                 2167 non-null   object
#  11  text                   2167 non-null   object
#  12  expanded_urls          2109 non-null   object
#  13  rating_numerator       2167 non-null   int64
#  14  rating_denominator     2167 non-null   int64
#  15  name                   2112 non-null   object
#  16  doggo                  2167 non-null   object
#  17  floofer                2167 non-null   object
#  18  pupper                 2167 non-null   object
#  19  puppo                  2167 non-null   object
# dtypes: datetime64[ns, UTC](2), float64(2), int64(5), object(11)
# memory usage: 355.5+ KB

# %%
# MERGE newly merged dataframe and image_preds to get new_tweets_df2
new_tweets_df2 = pd.merge(new_tweets_df, image_preds, on='tweet_id')

# %%
# data exploration
new_tweets_df2.head(5)
# Out:
#                  created_at            tweet_id  \
# 0 2017-08-01 16:23:56+00:00  892420643555336193
# 1 2017-08-01 00:17:27+00:00  892177421306343426
# 2 2017-07-31 00:18:03+00:00  891815181378084864
# 3 2017-07-30 15:58:51+00:00  891689557279858688
# 4 2017-07-29 16:00:24+00:00  891327558926688256
#
#                                            full_text display_text_range  \
# 0  This is Phineas. He's a mystical boy. Only eve...            [0, 85]
# 1  This is Tilly. She's just checking pup on you....           [0, 138]
# 2  This is Archie. He is a rare Norwegian Pouncin...           [0, 121]
# 3  This is Darla. She commenced a snooze mid meal...            [0, 79]
# 4  This is Franklin. He would like you to stop ca...           [0, 138]
#
#    retweet_count  favorite_count  \
# 0           7477           35388
# 1           5549           30638
# 2           3671           23034
# 3           7649           38689
# 4           8249           36965
#
#                                                 user  in_reply_to_status_id  \
# 0  {'id': 4196983835, 'id_str': '4196983835', 'na...                    NaN
# 1  {'id': 4196983835, 'id_str': '4196983835', 'na...                    NaN
# 2  {'id': 4196983835, 'id_str': '4196983835', 'na...                    NaN
# 3  {'id': 4196983835, 'id_str': '4196983835', 'na...                    NaN
# 4  {'id': 4196983835, 'id_str': '4196983835', 'na...                    NaN
#
#    in_reply_to_user_id                 timestamp  ... img_num           p1  \
# 0                  NaN 2017-08-01 16:23:56+00:00  ...       1       orange
# 1                  NaN 2017-08-01 00:17:27+00:00  ...       1    Chihuahua
# 2                  NaN 2017-07-31 00:18:03+00:00  ...       1    Chihuahua
# 3                  NaN 2017-07-30 15:58:51+00:00  ...       1  paper_towel
# 4                  NaN 2017-07-29 16:00:24+00:00  ...       2       basset
#
#     p1_conf  p1_dog                  p2   p2_conf p2_dog  \
# 0  0.097049   False               bagel  0.085851  False
# 1  0.323581    True            Pekinese  0.090647   True
# 2  0.716012    True            malamute  0.078253   True
# 3  0.170278   False  Labrador_retriever  0.168086   True
# 4  0.555712    True    English_springer  0.225770   True
#
#                             p3   p3_conf p3_dog
# 0                       banana  0.076110  False
# 1                     papillon  0.068957   True
# 2                       kelpie  0.031379   True
# 3                      spatula  0.040836  False
# 4  German_short-haired_pointer  0.175219   True
#
# [5 rows x 31 columns]

# %%
# data exploration
new_tweets_df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1986 entries, 0 to 1985
# Data columns (total 31 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   created_at             1986 non-null   datetime64[ns, UTC]
#  1   tweet_id               1986 non-null   int64
#  2   full_text              1986 non-null   object
#  3   display_text_range     1986 non-null   object
#  4   retweet_count          1986 non-null   int64
#  5   favorite_count         1986 non-null   int64
#  6   user                   1986 non-null   object
#  7   in_reply_to_status_id  23 non-null     float64
#  8   in_reply_to_user_id    23 non-null     float64
#  9   timestamp              1986 non-null   datetime64[ns, UTC]
#  10  source                 1986 non-null   object
#  11  text                   1986 non-null   object
#  12  expanded_urls          1986 non-null   object
#  13  rating_numerator       1986 non-null   int64
#  14  rating_denominator     1986 non-null   int64
#  15  name                   1931 non-null   object
#  16  doggo                  1986 non-null   object
#  17  floofer                1986 non-null   object
#  18  pupper                 1986 non-null   object
#  19  puppo                  1986 non-null   object
#  20  jpg_url                1986 non-null   object
#  21  img_num                1986 non-null   int64
#  22  p1                     1986 non-null   object
#  23  p1_conf                1986 non-null   float64
#  24  p1_dog                 1986 non-null   bool
#  25  p2                     1986 non-null   object
#  26  p2_conf                1986 non-null   float64
#  27  p2_dog                 1986 non-null   bool
#  28  p3                     1986 non-null   object
#  29  p3_conf                1986 non-null   float64
#  30  p3_dog                 1986 non-null   bool
# dtypes: bool(3), datetime64[ns, UTC](2), float64(5), int64(6), object(15)
# memory usage: 455.8+ KB

# %%
name_by_avgs = new_tweets_df2.groupby("p1")[['p1_conf','rating_numerator','rating_denominator','doggo','floofer','pupper','puppo','favorite_count',
                             'retweet_count']].mean()
name_by_avgs.head(10)
# Out:
#                                  p1_conf  rating_numerator  \
# p1
# Afghan_hound                    0.433959          9.666667
# African_crocodile               0.330625         10.000000
# African_grey                    0.270468         11.000000
# African_hunting_dog             0.733025          8.000000
# Airedale                        0.583771          9.833333
# American_Staffordshire_terrier  0.636330         10.833333
# American_black_bear             0.219166          8.000000
# Angora                          0.571526          7.000000
# Appenzeller                     0.503665         11.000000
# Arabian_camel                   0.682931         10.000000
#
#                                 rating_denominator  favorite_count  \
# p1
# Afghan_hound                                  10.0        15432.00
# African_crocodile                             10.0          864.00
# African_grey                                  10.0         4729.00
# African_hunting_dog                           10.0         1542.00
# Airedale                                      10.0         4716.75
# American_Staffordshire_terrier                10.0         5562.50
# American_black_bear                           10.0         4362.00
# Angora                                        10.0        42585.50
# Appenzeller                                   10.0         6553.00
# Arabian_camel                                 10.0        37607.50
#
#                                 retweet_count
# p1
# Afghan_hound                      5072.333333
# African_crocodile                  230.000000
# African_grey                      1094.000000
# African_hunting_dog               1021.000000
# Airedale                          1190.666667
# American_Staffordshire_terrier    1606.500000
# American_black_bear               1120.000000
# Angora                           14058.000000
# Appenzeller                       1227.500000
# Arabian_camel                    17424.000000

# %%
count_by_name = new_tweets_df2.groupby('p1')['p1_conf'].size()

# %%
count_by_name.head()
# Out:
# p1
# Afghan_hound            3
# African_crocodile       1
# African_grey            1
# African_hunting_dog     1
# Airedale               12
# Name: p1_conf, dtype: int64

# %%
top10_names = count_by_name.sort_values().tail(10)
top10_names
# Out:
# p1
# malamute               29
# toy_poodle             37
# Pomeranian             38
# Samoyed                39
# chow                   41
# pug                    54
# Chihuahua              79
# Pembroke               87
# Labrador_retriever     93
# golden_retriever      139
# Name: p1_conf, dtype: int64

# %%
top10_names.index.values
# Out:
# array(['malamute', 'toy_poodle', 'Pomeranian', 'Samoyed', 'chow', 'pug',
#        'Chihuahua', 'Pembroke', 'Labrador_retriever', 'golden_retriever'],
#       dtype=object)

# %%
top10_val_array = top10_names.values

# %%
top11to20_names = count_by_name.sort_values().tail(20)
top10_names

# %%
# Fixing random state for reproducibility
np.random.seed(19680801)


plt.rcdefaults()
fig, ax = plt.subplots()

# Example data
#people = ('Tom', 'Dick', 'Harry', 'Slim', 'Jim')
#performance = 3 + 10 * np.random.rand(len(people))

people = top10_names.index.values 

y_pos = np.arange(len(people))

performance = top10_names.values
error = np.random.rand(len(people))

ax.barh(y_pos, performance, xerr=error, align='center')
ax.set_yticks(y_pos)
ax.set_yticklabels(people)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('Dog Type (predicted) Count ')
ax.set_title('WeRateDogs Dog Breeds represented (top 10)')

plt.show()

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(6, 3), subplot_kw=dict(aspect="equal"))

names = top10_names.index.values 

'''["225 g flour",
          "90 g sugar",
          "1 egg",
          "60 g butter",
          "100 ml milk",
          "1/2 package of yeast"]
'''

data = top10_names.values

wedges, texts = ax.pie(data, wedgeprops=dict(width=0.5), startangle=-40)

bbox_props = dict(boxstyle="square,pad=0.3", fc="w", ec="k", lw=0.72)
kw = dict(arrowprops=dict(arrowstyle="-"),
          bbox=bbox_props, zorder=0, va="center")

for i, p in enumerate(wedges):
    ang = (p.theta2 - p.theta1)/2. + p.theta1
    y = np.sin(np.deg2rad(ang))
    x = np.cos(np.deg2rad(ang))
    horizontalalignment = {-1: "right", 1: "left"}[int(np.sign(x))]
    connectionstyle = "angle,angleA=0,angleB={}".format(ang)
    kw["arrowprops"].update({"connectionstyle": connectionstyle})
    ax.annotate(names[i], xy=(x, y), xytext=(1.35*np.sign(x), 1.4*y),
                horizontalalignment=horizontalalignment, **kw)

ax.set_title("WeRateDogs Top10 Name Distribution")

plt.show()

# %%
name_by_avgs

# %%
new_tweets_df2.iloc[300:305,0:10]
# Out:
#                    created_at            tweet_id  \
# 300 2017-01-24 17:04:50+00:00  823939628516474880
# 301 2017-01-24 01:08:40+00:00  823699002998870016
# 302 2017-01-23 17:20:14+00:00  823581115634085888
# 303 2017-01-23 00:13:17+00:00  823322678127919110
# 304 2017-01-22 01:12:59+00:00  822975315408461824
#
#                                              full_text display_text_range  \
# 300  This is Cash. He's officially given pup on tod...            [0, 79]
# 301  This is Winston. The goggles make him a superh...           [0, 135]
# 302  This is Crawford. He's quite h*ckin good at th...           [0, 106]
# 303  This is Wyatt. He's got the fastest paws in th...           [0, 106]
# 304  This is Albus. He's soaked as h*ck. Seems to h...           [0, 118]
#
#      retweet_count  favorite_count  \
# 300           2660           10508
# 301           2481           13827
# 302           2590           12889
# 303           3954           15570
# 304           3390           17166
#
#                                                   user  in_reply_to_status_id  \
# 300  {'id': 4196983835, 'id_str': '4196983835', 'na...                    NaN
# 301  {'id': 4196983835, 'id_str': '4196983835', 'na...                    NaN
# 302  {'id': 4196983835, 'id_str': '4196983835', 'na...                    NaN
# 303  {'id': 4196983835, 'id_str': '4196983835', 'na...                    NaN
# 304  {'id': 4196983835, 'id_str': '4196983835', 'na...                    NaN
#
#      in_reply_to_user_id                 timestamp
# 300                  NaN 2017-01-24 17:04:50+00:00
# 301                  NaN 2017-01-24 01:08:40+00:00
# 302                  NaN 2017-01-23 17:20:14+00:00
# 303                  NaN 2017-01-23 00:13:17+00:00
# 304                  NaN 2017-01-22 01:12:59+00:00

# %%
new_tweets_df2.iloc[300:305,11:20]
# Out:
#                                                   text  \
# 300  This is Cash. He's officially given pup on tod...
# 301  This is Winston. The goggles make him a superh...
# 302  This is Crawford. He's quite h*ckin good at th...
# 303  This is Wyatt. He's got the fastest paws in th...
# 304  This is Albus. He's soaked as h*ck. Seems to h...
#
#                                          expanded_urls  rating_numerator  \
# 300  https://twitter.com/dog_rates/status/823939628...                12
# 301  https://twitter.com/dog_rates/status/823699002...                12
# 302  https://twitter.com/dog_rates/status/823581115...                11
# 303  https://twitter.com/dog_rates/status/823322678...                11
# 304  https://twitter.com/dog_rates/status/822975315...                12
#
#      rating_denominator      name doggo floofer pupper puppo
# 300                  10      Cash     0       0      0     0
# 301                  10   Winston     0       0      0     0
# 302                  10  Crawford     0       0      0     0
# 303                  10     Wyatt     0       0      0     0
# 304                  10     Albus     0       0      0     0

# %%
 '''doggo, floofer, pupper, puppo  '''

desig = ['doggo', 'floofer', 'pupper', 'puppo']

#new_tweets_df2.groupby(desig)[desig].mean()

new_tweets_df2.doggo.mean()

new_tweets_df2[desig].mean()
# Out:
# doggo      0.036757
# floofer    0.004028
# pupper     0.106747
# puppo      0.011581
# dtype: float64

# %%
new_tweets_df2.name.value_counts()
# Out:
# None       546
# Charlie     10
# Cooper      10
# Oliver      10
# Lucy         9
#           ...
# Mabel        1
# Oshie        1
# Rumble       1
# Baron        1
# Zooey        1
# Name: name, Length: 933, dtype: int64
